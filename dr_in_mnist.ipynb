# %%
import matplotlib.pyplot as plt
from myplot import *
from mydr import *

# %%
data,label = extract_specific_categories('./dataset/fashionmnist/train.csv','label',[0,1,3,6,8,9])
data,label = extract_specific_amount(data,label,[0,1,3,6,8,9],1000)
# draw_image_array(3,10,data,0)
norm, pca, scaler, svc, reduced_data, label = eval_dimension_reduction_method(method='pca', n_components=2, data=data, label=label,params={'n_neighbors': 5, 'method': 'modified'})
# reduced_data = reduced_data/np.max(reduced_data,axis=0)
plt.figure(dpi=300)
plot_decision_boundary(svc.predict,reduced_data)
plot_multiclasses_2d_distribution(reduced_data, label,[0,1,3,6,8,9],['o','^','s','P','*','d'],min_dist=0.06)
# Out:
# D:\Anaconda\envs\lhd\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# learn time:0.143 inference time:0.045 score:0.701
# (6, 1000, 2)
# _data shape: (2664, 2)
